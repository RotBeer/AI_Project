# %% [markdown]
# # *DATA SCIENCE / SECTION 2* 프로젝트 설명서
# ---
# <img src='https://storage.googleapis.com/kaggle-datasets-images/1434901/2374680/80f96c0f81e1aacea469f2c54b22d9fe/dataset-cover.jpg?t=2021-06-27-18-11-19' width='500'>
#
# ## 개요
# ### 피싱 사이트란?
#  유명 사이트를 위장한 가짜 사이트를 통해 사용자의 로그인 ID, 패스워드, 신분증 촬영 등 개인정보를 탈취해 각종 공격을 하는 사이트입니다.
#
#  주로 금전적 피해를 일으키는 공격을 하는데 예금인출, 결재 대납, 명의 도용 등의 피해를 줍니다.
#
#  <img src='https://s3.amazonaws.com/cdn.freshdesk.com/data/helpdesk/attachments/production/31016513010/original/4ognmQfwZGIQJgZMkTInb6srfy_W_7n2CQ.png?1571646269' width='500'><br>
#  검색을 통해 위와 같은 사이트를 의심없이 접속하게 되는 경우
#
#  <img src='https://s3.amazonaws.com/cdn.freshdesk.com/data/helpdesk/attachments/production/31016548417/original/Jt2lZwElzQHCKxnPpDqlUR_pDDDKY2QxCA.png?1571738712' width='500'><br>
#  피싱 사이트를 진짜 사이트로 생각하여 개인정보를 입력합니다.
#
#  <img src='https://s3.amazonaws.com/cdn.freshdesk.com/data/helpdesk/attachments/production/31016549251/original/BI6eMq3GsJX2D2Dx0Zlc2UFzTeE0c1tUuw.png?1571740307' width='500'><br>
#  로그인정보를 입력 시 지속적인 로딩화면을 보여주거나 로그인에 실패하는 화면을 보여줍니다.
#
#
#  동시에 해커는 탈취한 정보로 진짜 사이트에 접속하여 가상화폐 등의 자산을 탈취합니다.
#
# ### 피싱사이트 접속 예방 수칙?
# 1. 인터넷 주소창에 자물쇠가 있는지 꼭 확인합니다.
# 2. 인터넷 주소(URL)가 정확한지 확인합니다.
# 3. 이메일 발신자 주소를 확인합니다.
# 4. 이메일에서 버튼 링크로 넘어올 때 특히 더 주의합니다.
# 5. 인터넷 검색보다는 직접 주소를 입력하거나 즐겨찾기를 이용합니다.
#
# ### 하지만...
# 피싱사이트에 의한 피해는 **무의식**중에 **의심없이** 인터넷을 사용하다가 발생합니다.
#
# 모든 사람이 '피싱사이트 접속 예방 수칙'을 외우고 다니면서 웹사이트에 접속할 때 마다 의심하며 사용할 수 는 없습니다.
#
# 무작위 대상을 공격하거나, 특정 개인이나 회사를 대상으로 하거나, 고위 경영 간부나 비즈니스 내 기타 고위직을 대상으로 하는 등 종류도 다양해졌습니다.
#
# 웹사이트를 만드는 기술 이외에 특별한 기술이 필요하지 않으며, 유명사이트를 똑같이 복제하는 것도 어렵지 않으며, 백신에도 검출 되지 않습니다.
#
# 이러한 특징들 때문에 피싱사이트들은 개인 및 금융 정보를 탈취하는 가장 성공적이고 효과적인 방법이 되었습니다.
#
# ### 그렇다면!
# 머신러닝을 가짜 사이트를 분류해내거나, 가짜 사이트일 확률이 높다면 사용자에게 경고하는 방식으로 사용 할 수 있을 것으로 보입니다.

# %% [markdown]
# # 사용한 Dataset (Kaggle)
# https://www.kaggle.com/datasets/shashwatwork/web-page-phishing-detection-dataset
#
# 캐글에 있는 데이터셋과 문제정의를 그대로 사용했습니다.
#
# 11430개의 url과 87개의 특징이 있습니다.
#
# 56개의 url에서 가져온 특징, 24개의 페이지에서 가져온 특징, 7개의 외부서비스에서 가져온 특징이 있습니다.
#
# 각각의 특징에 대한 설명은 제공되어 있지 않지만, 대부분의 특징의 이름이 명확하게 정의되어 있어 의미를 유추할 수 있습니다.
#
# 데이터셋은 피싱사이트 50%와 합법사이트 50%로 균형있게 구성되어있습니다.
#
# 캐글에 있는 자료는 원본자료를 가공한 것이고, 원본 자료는 여기서 구할수 있습니다.
#
# https://data.mendeley.com/datasets/c2gw7fy2j4/3
#
# 아쉽게도 원본 자료가 오류로 다운로드 할 수 없어 캐글에 있는 자료를 사용하겠습니다.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('~/dataset_phishing.csv')
df
# Out:
#                                                      url  length_url  \
# 0                  http://www.crestonwood.com/router.php          37
# 1      http://shadetreetechnology.com/V4/validation/a...          77
# 2      https://support-appleld.com.secureupdate.duila...         126
# 3                                     http://rgipt.ac.in          18
# 4      http://www.iracing.com/tracks/gateway-motorspo...          55
# ...                                                  ...         ...
# 11425      http://www.fontspace.com/category/blackletter          45
# 11426  http://www.budgetbots.com/server.php/Server%20...          84
# 11427  https://www.facebook.com/Interactive-Televisio...         105
# 11428             http://www.mypublicdomainpictures.com/          38
# 11429  http://174.139.46.123/ap/signin?openid.pape.ma...         477
#
#        length_hostname  ip  nb_dots  nb_hyphens  nb_at  nb_qm  nb_and  nb_or  \
# ...

# %% [markdown]
# # Part 1. 데이터 전처리, EDA, 시각화
#
# ## 데이터 전처리
# 원본데이터를 가공하여 머신러닝에 바로 사용할 수 있도록 전처리를 마친 것으로 보입니다.
#
# 데이터 타입과 결측치 여부를 확인 해보겠습니다.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11430 entries, 0 to 11429
# Data columns (total 89 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   url                         11430 non-null  object
#  1   length_url                  11430 non-null  int64
#  2   length_hostname             11430 non-null  int64
#  3   ip                          11430 non-null  int64
#  4   nb_dots                     11430 non-null  int64
#  5   nb_hyphens                  11430 non-null  int64
#  6   nb_at                       11430 non-null  int64
#  7   nb_qm                       11430 non-null  int64
#  8   nb_and                      11430 non-null  int64
#  9   nb_or                       11430 non-null  int64
#  10  nb_eq                       11430 non-null  int64
#  11  nb_underscore               11430 non-null  int64
#  12  nb_tilde                    11430 non-null  int64
# ...

# %%
df.describe()
# Out:
#          length_url  length_hostname            ip       nb_dots  \
# count  11430.000000     11430.000000  11430.000000  11430.000000
# mean      61.126684        21.090289      0.150569      2.480752
# std       55.297318        10.777171      0.357644      1.369686
# min       12.000000         4.000000      0.000000      1.000000
# 25%       33.000000        15.000000      0.000000      2.000000
# 50%       47.000000        19.000000      0.000000      2.000000
# 75%       71.000000        24.000000      0.000000      3.000000
# max     1641.000000       214.000000      1.000000     24.000000
#
#          nb_hyphens         nb_at         nb_qm        nb_and    nb_or  \
# count  11430.000000  11430.000000  11430.000000  11430.000000  11430.0
# mean       0.997550      0.022222      0.141207      0.162292      0.0
# std        2.087087      0.155500      0.364456      0.821337      0.0
# min        0.000000      0.000000      0.000000      0.000000      0.0
# ...

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df.status
# Out:
# 0        legitimate
# 1          phishing
# 2          phishing
# 3        legitimate
# 4        legitimate
#             ...
# 11425    legitimate
# 11426      phishing
# 11427    legitimate
# 11428    legitimate
# 11429      phishing
# Name: status, Length: 11430, dtype: object

# %% [markdown]
# 결측치는 없고, url과 target인 status를 제외한 특징들은 모두 숫자형인 것을 알 수 있습니다.
#
# status를 phishing->1, legitmate->0 으로 바꿔주겠습니다.

# %%
df_cp = df.copy()
df_cp['status'] = df_cp.status.apply(lambda x: 1 if x=='phishing' else 0).astype(int)
df_cp
# Out:
#                                                      url  length_url  \
# 0                  http://www.crestonwood.com/router.php          37
# 1      http://shadetreetechnology.com/V4/validation/a...          77
# 2      https://support-appleld.com.secureupdate.duila...         126
# 3                                     http://rgipt.ac.in          18
# 4      http://www.iracing.com/tracks/gateway-motorspo...          55
# ...                                                  ...         ...
# 11425      http://www.fontspace.com/category/blackletter          45
# 11426  http://www.budgetbots.com/server.php/Server%20...          84
# 11427  https://www.facebook.com/Interactive-Televisio...         105
# 11428             http://www.mypublicdomainpictures.com/          38
# 11429  http://174.139.46.123/ap/signin?openid.pape.ma...         477
#
#        length_hostname  ip  nb_dots  nb_hyphens  nb_at  nb_qm  nb_and  nb_or  \
# ...

# %% [markdown]
# ## EDA
# 현재 Dataset에는 87개의 특징이 있고 모두 url에서 추출하거나 url로 접속한 뒤 알 수 있는 정보로 보입니다.
# - length_url: url의 길이
# - nb_dots: url의 dot(.)의 개수
# - ratio_digits_url: url에서 숫자의 비율
#
# 특징들이 의미하는 바를 추측할수 없는 2가지 이유가 있습니다.
# 1. 피싱사이트의 url로 접속을 시도하면 지금은 접속이 차단되었거나 서비스가 종료되었습니다.
# 2. 원본자료에 설명이 있을 것으로 보이지만 현재 오류로 사용할 수 없습니다.
#
# 따라서 다음과 같은 특징들은 의미를 추측하기 힘듭니다.
# - google_index와 page_rank: 구글에 검색했을 때 페이지 번호와 인덱스를 보여주는 것으로 보이지만 알 수 없습니다.
# - login_form: url로 접속한 페이지에 login_form의 존재 유무로 보입니다.
# - ip와 port: 0과 1의 값이지만 의미를 알 수 없습니다.
#
# 이러한 점들을 고려하여 적절한 특징들만 추려내어 사용하도록 하겠습니다.
# 1. url: 원본 url
# 2. length_url: url의 길이
# 3. length_hostname: hostname의 길이
# 4. nb_dots: . 개수
# 5. nb_hyphens: - 개수
# 6. nb_at: @ 개수
# 7. nb_qm: ? 개수
# 8. nb_and: & 개수
# 9. nb_eq: = 개수
# 10. nb_underscore: _ 개수
# 11. nb_tilde: ~ 개수
# 12. nb_percent: % 개수
# 13. nb_slash: / 개수
# 14. nb_star: * 개수
# 15. nb_colon: : 개수
# 16. nb_comma: , 개수
# 17. nb_semicolumn: ; 개수
# 18. nb_dollar: $ 개수
# 19. nb_space:   개수
# 20. nb_www: www 개수
# 21. nb_com: com 개수
# 22. nb_dslash: \ 개수
# 23. http_in_path: http 개수
# 24. ratio_digits_url: url 숫자 비율
# 25. ratio_digits_host: host 숫자 비율
# 26. nb_subdomains: 서브도메인 개수
# 27. nb_redirection: redirection 개수
# 28. nb_external_redirection 외부 redirection 개수
# 29. shortest_word_host: host에서 가장 짧은 단어의 길이
# 30. shortest_word_path: path에서 가장 짧은 단어의 길이
# 31. longest_word_host: host에서 가장 긴 단어의 길이
# 32. longest_word_path: path에서 가장 긴 단어의 길이
# 33. avg_word_host: host에서 단어 길이의 평균
# 34. avg_word_path: path에서 단어 길이의 평균
# 35. status: 피싱사이트 여부 target

# %%
df_cp.columns[df_cp.nunique() <= 1] # 카디널리티가 1인 특징
# Out:
# Index(['nb_or', 'ratio_nullHyperlinks', 'ratio_intRedirection',
#        'ratio_intErrors', 'submit_email', 'sfh'],
#       dtype='object')

# %%
features = ['length_url', 'length_hostname', 'nb_dots', 'nb_hyphens', 'nb_at', 'nb_qm', 'nb_and', 'nb_eq', 'nb_underscore',
 'nb_tilde', 'nb_percent', 'nb_slash', 'nb_star', 'nb_colon', 'nb_comma', 'nb_semicolumn', 'nb_dollar', 'nb_space', 'nb_www',
 'nb_com', 'nb_dslash', 'http_in_path', 'ratio_digits_url', 'ratio_digits_host', 'nb_subdomains', 'nb_redirection', 'nb_external_redirection', 'shortest_word_host', 'shortest_word_path',
 'longest_word_host', 'longest_word_path', 'avg_word_host', 'avg_word_path']
target = 'status'

# %% [markdown]
# ## 시각화
# 우선, 전체 데이터에서 target의 분포를 살펴보겠습니다.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(16,10), facecolor='white')
# sns.set_style('darkgrid')
sns.countplot(data=df, x='status')
plt.show()

# %% [markdown]
# target은 50:50으로 균등한 분포를 보이므로 추가작업을 진행할 필요는 없어보입니다.
#
# 데이터를 살펴 봤을 때 length_url이 타겟과 가장 연관성이 있어보이는데, 한번 시각화로 살펴보겠습니다.

# %%
df_g = df_cp[['length_url', 'status']].groupby('length_url').mean().reset_index()
plt.figure(figsize=(16,10), facecolor='white')
sns.lineplot(data=df_g, x='length_url', y='status')
plt.show()

# %% [markdown]
# length_url의 값이 클수록 피싱사이트의 비율이 높아지는 것으로 보입니다.
#
# 특히, 200보다 큰 경우에 매우 높은 확률로 피싱사이트인 것을 알 수 있습니다.

# %% [markdown]
# # Part 2. 모델링 및 모델 해석
# ## 모델링
# 주어진 데이터로 모델링을 해보겠습니다.

# %%
from sklearn.model_selection import train_test_split

features = ['length_url', 'length_hostname', 'nb_dots', 'nb_hyphens', 'nb_at', 'nb_qm', 'nb_and', 'nb_eq', 'nb_underscore',
 'nb_tilde', 'nb_percent', 'nb_slash', 'nb_colon', 'nb_semicolumn', 'nb_space', 'nb_www',
 'nb_com', 'nb_dslash', 'http_in_path', 'ratio_digits_url', 'ratio_digits_host', 'nb_redirection', 'shortest_word_host', 'shortest_word_path',
 'longest_word_host', 'longest_word_path', 'avg_word_host', 'avg_word_path']
target = 'status'

X = df_cp[features]
y = df_cp[target]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((9144, 28), (2286, 28), (9144,), (2286,))

# %%
from sklearn.metrics import classification_report

baseline = len(y_train) * [y_train.mode()[0]]
print(classification_report(y_train, baseline))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67      4572
#            1       0.00      0.00      0.00      4572
#
#     accuracy                           0.50      9144
#    macro avg       0.25      0.50      0.33      9144
# weighted avg       0.25      0.50      0.33      9144
# /home/turtle/.local/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/turtle/.local/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from xgboost import XGBClassifier
from scipy.stats.distributions import uniform
from sklearn.model_selection import RandomizedSearchCV

xgb = XGBClassifier(
        objective="binary:logistic",
        eval_metric="error",
        n_estimators=200,
        random_state=42,
        n_jobs=-1,
        learning_rate=0.1,
        use_label_encoder=False,
    )

params = {
    "xgbclassifier__max_depth": [2, 4, 6, 8],
    "xgbclassifier__min_child_weight": [2, 4, 8, 16],
    "xgbclassifier__colsample_bytree": uniform(loc=0.5, scale=0.5),
}

randomized_search = RandomizedSearchCV(
    xgb,
    param_distributions=params,
    scoring="roc_auc",
    n_iter=10,
    cv=5,
    verbose=3,
    random_state=42,
)
randomized_search.fit(X_train, y_train)
print("최적 하이퍼파라미터: ", randomized_search.best_params_)
print("최적 AUC: ", randomized_search.best_score_)
# Out:
# /home/turtle/.local/lib/python3.6/site-packages/pkg_resources/__init__.py:119: PkgResourcesDeprecationWarning: 0.18ubuntu0.18.04.1 is an invalid version and will not be supported in a future release
#   PkgResourcesDeprecationWarning,
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [14:04:12] WARNING: ../src/learner.cc:576:
# Parameters: { "xgbclassifier__colsample_bytree", "xgbclassifier__max_depth", "xgbclassifier__min_child_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5] END xgbclassifier__colsample_bytree=0.6872700594236812, xgbclassifier__max_depth=2, xgbclassifier__min_child_weight=8;, score=0.957 total time=   1.0s
# [14:04:13] WARNING: ../src/learner.cc:576:
# ...

# %%
print(classification_report(y_train, randomized_search.predict(X_train)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.94      4572
#            1       0.94      0.93      0.94      4572
#
#     accuracy                           0.94      9144
#    macro avg       0.94      0.94      0.94      9144
# weighted avg       0.94      0.94      0.94      9144

# %%
import eli5
from eli5.sklearn import PermutationImportance

# permuter 정의
permuter = PermutationImportance(
    randomized_search,  # model
    scoring="accuracy",  # metric
    n_iter=10,  # 다른 random seed를 사용하여 100번 반복
    random_state=42,
)

# 스코어를 다시 계산합니다.
permuter.fit(X_train, y_train)

feature_names = X_test.columns.tolist()
pi = pd.Series(permuter.feature_importances_, feature_names).sort_values()
plt.figure(figsize=(16,10), facecolor='white')
pi.plot.barh()
plt.title("Permutation Importance")
# Out:
# Text(0.5, 1.0, 'Permutation Importance')

# %%
pi
# Out:
# nb_colon              0.000033
# nb_tilde              0.000055
# nb_percent            0.000230
# http_in_path          0.000328
# nb_dslash             0.000328
# nb_space              0.000481
# nb_eq                 0.000558
# nb_com                0.000776
# nb_and                0.000842
# nb_semicolumn         0.001455
# nb_at                 0.004068
# avg_word_path         0.008913
# nb_qm                 0.009624
# nb_redirection        0.011625
# longest_word_host     0.012905
# avg_word_host         0.014676
# nb_underscore         0.015179
# ratio_digits_host     0.020516
# length_url            0.025077
# shortest_word_host    0.025098
# shortest_word_path    0.025951
# longest_word_path     0.028959
# nb_hyphens            0.034099
# nb_dots               0.035903
# ratio_digits_url      0.036024
# length_hostname       0.054199
# nb_slash              0.075022
# nb_www                0.127231
# dtype: float64

# %%
from pdpbox.pdp import pdp_isolate, pdp_plot

target_feature = "nb_www"

isolated = pdp_isolate(
    model=randomized_search,
    dataset=X_train,
    model_features=X_train.columns,
    feature=target_feature,
    grid_type="percentile",  # default = 'percentile', or 'equal'
    num_grid_points=10,  # default = 10
)

fig, ax = pdp_plot(isolated,
    feature_name=target_feature,
    plot_lines=True,  # ICE plots
    frac_to_plot=50,  # float type을 입력하면 전체 데이터 갯수 중 plotting할 데이터 수의 비율이 됩니다. int type을 입력하면 데이터의 수가 됩니다.
    plot_pts_dist=True,)

fig.set_facecolor('white')
plt.show()

# %%
target_feature = "nb_slash"

isolated = pdp_isolate(
    model=randomized_search,
    dataset=X_train,
    model_features=X_train.columns,
    feature=target_feature,
    grid_type="percentile",  # default = 'percentile', or 'equal'
    num_grid_points=10,  # default = 10
)
fig, ax = pdp_plot(isolated,
    feature_name=target_feature,
    plot_lines=True,  # ICE plots
    frac_to_plot=50,  # float type을 입력하면 전체 데이터 갯수 중 plotting할 데이터 수의 비율이 됩니다. int type을 입력하면 데이터의 수가 됩니다.
    plot_pts_dist=True,)

fig.set_facecolor('white')
plt.show()

# %%
target_feature = "length_hostname"

isolated = pdp_isolate(
    model=randomized_search,
    dataset=X_train,
    model_features=X_train.columns,
    feature=target_feature,
    grid_type="percentile",  # default = 'percentile', or 'equal'
    num_grid_points=10,  # default = 10
)
fig, ax = pdp_plot(isolated,
    feature_name=target_feature,
    plot_lines=True,  # ICE plots
    frac_to_plot=50,  # float type을 입력하면 전체 데이터 갯수 중 plotting할 데이터 수의 비율이 됩니다. int type을 입력하면 데이터의 수가 됩니다.
    plot_pts_dist=True,)

fig.set_facecolor('white')
plt.show()

# %% [markdown]
# 여기까지의 모델링의 전체 과정을 결과를 바탕으로 반복하겠습니다.
#
# 이후, test 데이터로 최종 결과를 보겠습니다.

# %%
print(classification_report(y_test, randomized_search.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89      1143
#            1       0.89      0.89      0.89      1143
#
#     accuracy                           0.89      2286
#    macro avg       0.89      0.89      0.89      2286
# weighted avg       0.89      0.89      0.89      2286

# %%
from sklearn.metrics import plot_confusion_matrix

fig, ax = plt.subplots(figsize=(10, 10), facecolor='white')
plot_confusion_matrix(randomized_search, X_test, y_test, ax= ax)
plt.show()
